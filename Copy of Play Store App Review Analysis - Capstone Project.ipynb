# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1='/content/drive/MyDrive/alma better/data/python_capestone_project/Copy of Play Store App Review Analysis - Capstone Project.ipynb'
review=pd.read_csv(path1)

# %%
path2='/content/drive/MyDrive/alma better/data/python_capestone_project/Copy of Play Store Data.csv'
play_store_data=pd.read_csv(path2)

# %%
play_store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
play_store_data.head(2)
# Out:
#                                               App  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                             Coloring book moana  ...  4.0.3 and up
#
# [2 rows x 13 columns]

# %%
#cleaning the data
play_store_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
# filling null values
play_store_data.fillna('missing', inplace=True)
play_store_data[['Current Ver','Android Ver']].fillna('Varies with device', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
#droping duplicates
play_store_data=play_store_data.drop_duplicates()

# %%
play_store_data[['Installs']].datatype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-07bf8c772f64> in <module>()
# ----> 1 play_store_data[['Installs']].datatype()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datatype'

# %%
play_store_data[['Reviews']].select_dtypes(Reviews= 'str')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-5124262a1ab5> in <module>()
# ----> 1 play_store_data[['Reviews']].select_dtypes(Reviews= 'str')
#
# TypeError: select_dtypes() got an unexpected keyword argument 'Reviews'

# %%
play_store_data.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
#minimum android requirment for a popular application
popular=pd.DataFrame(play_store_data.groupby(['Android Ver'])['Installs'])
plt.hist(play_store_data.groupby(['Android Ver'])['Installs'], color='green')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-7c6d18ffeb49> in <module>()
#       1 #minimum android requirment for a popular application
#       2 popular=pd.DataFrame(play_store_data.groupby(['Android Ver'])['Installs'])
# ----> 3 plt.hist(play_store_data.groupby(['Android Ver'])['Installs'], color='green')
#       4 plt.xlabel('Age')
#       5 plt.ylabel('Frequency')
#
# ...

# %%
age = dating_data[~dating_data['age'].isna()]['age']
plt.hist(age.values, color='green')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-3b888716055e> in <module>()
# ----> 1 age = dating_data[~dating_data['age'].isna()]['age']
#       2 plt.hist(age.values, color='green')
#       3 plt.xlabel('Age')
#       4 plt.ylabel('Frequency')
#
# NameError: name 'dating_data' is not defined
